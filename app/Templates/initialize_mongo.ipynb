# %%
import numpy as np
import pandas as pd
import pymongo
import requests
import os 
from bson.json_util import loads, dumps
import templates
import inspect

# %%
mongo_user = os.environ['MONGO_INITDB_ROOT_USERNAME']
mongo_pwd= os.environ['MONGO_INITDB_ROOT_PASSWORD']
mongo_initdb = os.environ['MONGO_INITDB_DATABASE']

# %%
classes = []
standards = []
topics = []
grade_levels = []
questions = []
answers = []
wrong_answers = []
for name, obj in inspect.getmembers(templates):
    if inspect.isclass(obj):
        classes.append(obj)

# %%
for j in range(len(classes)):
    try: 
        x = classes[j]()
        wrong_answer = x.wrong_answers
        wrong_answers.append(wrong_answer)
        question = x.question
        questions.append(question)
        standard = x.attr1 
        topic = x.attr2 
        topics.append(topic)
        grade_level = x.attr3 
        standards.append(standard)
        grade_levels.append(grade_level)
        answer = x.answer
        answers.append(answer)
    except:
        print("This question is not multiple choice.")
        question = x.question
        questions.append(question)
        standard = x.attr1 
        topic = x.attr2 
        topics.append(topic)
        grade_level = x.attr3 
        standards.append(standard)
        grade_levels.append(grade_level)
        answer = x.answer
        answers.append(answer)
        wrong_answer = "N/A"
        wrong_answers.append(wrong_answer)
        
print(len(classes))
print(len(standards))
print(len(questions))
print(len(grade_levels))
print(len(answers))
print(len(wrong_answers))
# Out:
# This question is not multiple choice.
# This question is not multiple choice.
# This question is not multiple choice.
# This question is not multiple choice.
# This question is not multiple choice.
# 45
# 45
# 45
# 45
# 45
# 45
# /solmathdashboard/app/Templates/templates.py:736: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   wrong = np.unique(wrong[wrong!=answer])
# /solmathdashboard/app/Templates/templates.py:678: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   wrong = np.unique(wrong[wrong!=answer])
# /solmathdashboard/app/Templates/templates.py:1110: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   wrong = np.unique(wrong[wrong!=answer])
# /solmathdashboard/app/Templates/templates.py:1168: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   wrong = np.unique(wrong[wrong!=answer])

# %%
df = pd.DataFrame({"Question": questions, "Answer": answers, "Wrong Answers": wrong_answers, "Grade_level": grade_levels, "Standard": standards, "Topic": topics})

# %%
df
# Out:
#                                              Question  \
# 0   Which number makes this equation true? 7 X ___...
# 1                                 4,305 + 1,612 = ___
# 2                                 7,784 - 1,626 = ___
# 3                                   12.1 + 12.5 = ___
# 4   Levi drinks 1.31 liters of Gatorade. Gina drin...
# 5            Which division statement represents 6/9?
# 6                    What is the sum of 7/12 and 6/6?
# 7        What is the difference between 9/4 and 4/12?
# 8   Which number is the largest common factor of 3...
# 9     What is the least common multiple of 24 and 30?
# 10  Antonio has 6 bags of 4 Skittles. Robin has 5 ...
# 11  Denari has 12 bags of 13 Reese's Pieces. How m...
# 12  Tyrek has 8 profiles with 5 Fornite skins. How...
# 13  Sam has 20 bags of 7 Skittles. How many Skittl...
# 14  Reese sold 448 Fortnite action figures. Each b...
# 15  Batman does 25 sit-ups 8 times per day. What i...
# 16            Use any method you want to find 10 X 8.
# 17                  What is the product of 69 and 75?
# 18  Gina poured 6 ounces of Gatorade into each of ...
# 19      What is the difference between 3,894 and 615?
# 20  Antonio ran a total of 90 minutes in a 2-day p...
# 21  At a store, Girlscout cookie boxes cost $26 ea...
# 22  This graph shows the morning temperature in a ...
# 23  Which figure with less than eight angles has t...
# 24  Katie has 9 gallons of soda. What is the total...
# 25                         9 meters = ___ centimeters
# 26  Flora's turtle weighed 7 pounds. What is the t...
# 27  A lacrosse team left the school at 2:37 P.M. a...
# 28  The table shows the time it took 4 students to...
# 29                           Which statement is true?
# 30                 How is 5,078,811 written in words?
# 31                      How is 6.71 written in words?
# 32  Which of the four following numbers is smalles...
# 33        What digit is in the tenths place in 10.44?
# 34  Which number, when rounded to the nearest whol...
# 35  Order these fractions from least to greatest: ...
# 36  Which fraction on the number line is the red p...
# 37  What digit is in the ten thousands place in th...
# 38  What is the value of the tens place in the num...
# 39  What is 6,739,381 rounded to the nearest ten t...
# 40  This is an increasing pattern: 9, 14, 19, 24, ...
# 41  The table shows the total number of players on...
# 42  Flora has a coin with one side heads and one s...
# 43  Sam rolls a fair number cube labeled 1 through...
# 44  Tyrek has 4 blue, 4 red, 4 yellow, and 4 purpl...
#
#                                                Answer  \
# 0                                                  11
# 1                                               5,917
# 2                                               6,158
# 3                                                24.6
# 4                                               0.947
# 5                                      6 divided by 9
# 6                                            1.583333
# 7                                            1.916667
# 8                                                  30
# 9                                                 120
# 10                                                119
# 11                                                156
# 12                                                 40
# 13                                                140
# 14                                             $2,240
# 15                                              1,400
# 16                                                 80
# 17                                              5,175
# 18                                                 12
# 19                                              3,279
# 20                                                 40
# 21                                             $1,300
# 22                                             Monday
# 23                                           heptagon
# 24                                                 72
# 25                                                900
# 26                                                112
# 27                                  5 hours 1 minutes
# 28                                              13.48
# 29                                      8,431 < 8,558
# 30  five million, seventy-eight thousand, eight hu...
# 31                                six point seven one
# 32                                              13.16
# 33                                                  4
# 34                                                8.6
# 35                                  [0.125, 1.0, 1.5]
# 36                                               0.25
# 37                                                  4
# 38                                                 20
# 39                                          6,740,000
# 40                                              Add 5
# 41                                                 11
# 42                                                0.5
# 43                                           0.166667
# 44                                         Impossible
#
#                                         Wrong Answers  Grade_level  \
# 0                                           [9, 4, 3]            4
# 1                            [10,312, 11,762, 18,083]            4
# 2                               [5,859, 5,535, 2,792]            4
# 3                                  [38.6, 31.0, 34.1]            4
# 4                   [0.95, 1.7229999999999999, 1.127]            4
# 5    [9 divided by 6, 2 divided by 8, 2 divided by 9]            4
# 6                                                 N/A            4
# 7                                                 N/A            4
# 8                                           [4, 7, 3]            4
# 9                                           [9, 3, 6]            4
# 10                                     [34, 199, 225]            4
# 11                                       [25, 81, 55]            4
# 12                                      [13, 39, 180]            4
# 13                                       [27, 15, 26]            4
# 14                             [$453, $2,424, $1,304]            4
# 15                                     [40, 216, 480]            4
# 16                                       [18, 54, 35]            4
# 17                                [144, 5,293, 2,257]            4
# 18                                         [8, 65, 9]            4
# 19                              [4,079, 4,392, 1,298]            4
# 20                                       [20, 30, 50]            4
# 21                              [$77, $1,400, $1,000]            4
# 22                       [Sunday, Wednesday, Tuesday]            4
# 23                       [pentagon, hexagon, decagon]            4
# 24                                       [17, 48, 16]            4
# 25                                    [700, 500, 800]            4
# 26                                       [23, 48, 32]            4
# 27  [4 hours 57 minutes, 1 hours 15 minutes, 1 hou...            4
# 28                                                N/A            4
# 29  [8,558 < 8,431, 8,383,108 < 8,247,076, 8,354,6...            4
# 30  [five million, seventy-eight thousand, seven h...            4
# 31  [six point seven, six point seven, six hundred...            4
# 32                              [13.71, 13.17, 13.36]            4
# 33                                          [8, 0, 5]            4
# 34                                [7.6, 7.565, 7.515]            4
# 35                                                N/A            4
# 36                                                N/A            4
# 37                                          [1, 5, 3]            4
# 38                                        [0, 7, 200]            4
# 39                  [7,000,000, 6,739,400, 6,739,000]            4
# 40                              [Add 9, Add 4, Add 8]            4
# 41                                       [84, 13, 12]            4
# 42                                          [7, 6, 8]            4
# 43                                          [1, 9, 8]            4
# 44  [Likely, but not certain, Unlikely, but not im...            4
#
#                                              Standard  \
# 0   Probability, Statistics, Patterns, Functions, ...
# 1                          Computation and Estimation
# 2                          Computation and Estimation
# 3                          Computation and Estimation
# 4                          Computation and Estimation
# 5                          Computation and Estimation
# 6                          Computation and Estimation
# 7                          Computation and Estimation
# 8                          Computation and Estimation
# 9                          Computation and Estimation
# 10                         Computation and Estimation
# 11                         Computation and Estimation
# 12                         Computation and Estimation
# 13                         Computation and Estimation
# 14                         Computation and Estimation
# 15                         Computation and Estimation
# 16                         Computation and Estimation
# 17                         Computation and Estimation
# 18                         Computation and Estimation
# 19                         Computation and Estimation
# 20                         Computation and Estimation
# 21                         Computation and Estimation
# 22  Probability, Statistics, Patterns, Functions, ...
# 23                           Measurement and Geometry
# 24                           Measurement and Geometry
# 25                           Measurement and Geometry
# 26                           Measurement and Geometry
# 27                           Measurement and Geometry
# 28                            Number and Number Sense
# 29                            Number and Number Sense
# 30                            Number and Number Sense
# 31                            Number and Number Sense
# 32                            Number and Number Sense
# 33                            Number and Number Sense
# 34                            Number and Number Sense
# 35                            Number and Number Sense
# 36                            Number and Number Sense
# 37                            Number and Number Sense
# 38                            Number and Number Sense
# 39                            Number and Number Sense
# 40  Probability, Statistics, Patterns, Functions, ...
# 41  Probability, Statistics, Patterns, Functions, ...
# 42  Probability, Statistics, Patterns, Functions, ...
# 43  Probability, Statistics, Patterns, Functions, ...
# 44  Probability, Statistics, Patterns, Functions, ...
#
#                             Topic
# 0                         Algebra
# 1            Addition/Subtraction
# 2            Addition/Subtraction
# 3    Decimal Addition/Subtraction
# 4    Decimal Addition/Subtraction
# 5                        Division
# 6   Fraction Addition/Subtraction
# 7   Fraction Addition/Subtraction
# 8                   Common Factor
# 9           Least Common Multiple
# 10                 Multiplication
# 11                 Multiplication
# 12                 Multiplication
# 13                 Multiplication
# 14                 Multiplication
# 15                 Multiplication
# 16                 Multiplication
# 17                 Multiplication
# 18                 Multiplication
# 19           Addition/Subtraction
# 20                       Division
# 21                 Multiplication
# 22                          Graph
# 23                       Geometry
# 24                    Measurement
# 25                    Measurement
# 26                    Measurement
# 27                   Time Elapsed
# 28             Decimal Comparison
# 29              Number Comparison
# 30                Number in Words
# 31               Decimal in Words
# 32             Decimal Comparison
# 33            Decimal Place Value
# 34               Decimal Rounding
# 35              Fraction Ordering
# 36           Fraction Number Line
# 37                    Place Value
# 38                    Place Value
# 39                       Rounding
# 40                       Patterns
# 41                       Patterns
# 42                    Probability
# 43                    Probability
# 44                    Probability

# %%
questions_json = df.to_dict('records')
questions_json
# Out:
# [{'Question': 'Which number makes this equation true? 7 X ___ = 77',
#   'Answer': 11,
#   'Wrong Answers': [9, 4, 3],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Algebra'},
#  {'Question': '4,305 + 1,612 = ___',
#   'Answer': '5,917',
#   'Wrong Answers': ['10,312', '11,762', '18,083'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Addition/Subtraction'},
#  {'Question': '7,784 - 1,626 = ___',
#   'Answer': '6,158',
#   'Wrong Answers': ['5,859', '5,535', '2,792'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Addition/Subtraction'},
#  {'Question': '12.1 + 12.5 = ___',
#   'Answer': 24.6,
#   'Wrong Answers': [38.6, 31.0, 34.1],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Decimal Addition/Subtraction'},
#  {'Question': 'Levi drinks 1.31 liters of Gatorade. Gina drinks 0.363 liters of Gatorade. How much more Gatorade does Levi drink than Gina?',
#   'Answer': 0.9470000000000001,
#   'Wrong Answers': [0.95, 1.7229999999999999, 1.127],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Decimal Addition/Subtraction'},
#  {'Question': 'Which division statement represents 6/9?',
#   'Answer': '6 divided by 9',
#   'Wrong Answers': ['9 divided by 6', '2 divided by 8', '2 divided by 9'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Division'},
#  {'Question': 'What is the sum of 7/12 and 6/6?',
#   'Answer': 1.5833333333333335,
#   'Wrong Answers': 'N/A',
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Fraction Addition/Subtraction'},
#  {'Question': 'What is the difference between 9/4 and 4/12?',
#   'Answer': 1.9166666666666667,
#   'Wrong Answers': 'N/A',
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Fraction Addition/Subtraction'},
#  {'Question': 'Which number is the largest common factor of 30, 60, and 90?',
#   'Answer': 30,
#   'Wrong Answers': [4, 7, 3],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Common Factor'},
#  {'Question': 'What is the least common multiple of 24 and 30?',
#   'Answer': 120,
#   'Wrong Answers': [9, 3, 6],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Least Common Multiple'},
#  {'Question': 'Antonio has 6 bags of 4 Skittles. Robin has 5 bags of 19 Skittles. How many Skittles do they have altogether?',
#   'Answer': 119,
#   'Wrong Answers': [34, 199, 225],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': "Denari has 12 bags of 13 Reese's Pieces. How many Reese's Pieces does she have?",
#   'Answer': 156,
#   'Wrong Answers': [25, 81, 55],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Tyrek has 8 profiles with 5 Fornite skins. How many Fornite skins does he have?',
#   'Answer': 40,
#   'Wrong Answers': [13, 39, 180],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Sam has 20 bags of 7 Skittles. How many Skittles does he have?',
#   'Answer': 140,
#   'Wrong Answers': [27, 15, 26],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Reese sold 448 Fortnite action figures. Each box cost $5. What was the total cost of all the Fortnite action figures sold?',
#   'Answer': '$2,240',
#   'Wrong Answers': ['$453', '$2,424', '$1,304'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Batman does 25 sit-ups 8 times per day. What is the total number of sit-ups Batman does in 7 days?',
#   'Answer': '1,400',
#   'Wrong Answers': [40, 216, 480],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Use any method you want to find 10 X 8.',
#   'Answer': 80,
#   'Wrong Answers': [18, 54, 35],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'What is the product of 69 and 75?',
#   'Answer': '5,175',
#   'Wrong Answers': [144, '5,293', '2,257'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'Gina poured 6 ounces of Gatorade into each of 2 glasses. Exactly how many ounces of Gatorade did Gina pour into all of these glasses?',
#   'Answer': 12,
#   'Wrong Answers': [8, 65, 9],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': 'What is the difference between 3,894 and 615?',
#   'Answer': '3,279',
#   'Wrong Answers': ['4,079', '4,392', '1,298'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Addition/Subtraction'},
#  {'Question': 'Antonio ran a total of 90 minutes in a 2-day period. He ran the same number of minutes each day. What is the closest to the number of minutes Antonio ran each day?',
#   'Answer': 40,
#   'Wrong Answers': [20, 30, 50],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Division'},
#  {'Question': 'At a store, Girlscout cookie boxes cost $26 each. Which is closest to the total cost of 51 Girlscout cookie boxes?',
#   'Answer': '$1,300',
#   'Wrong Answers': ['$77', '$1,400', '$1,000'],
#   'Grade_level': 4,
#   'Standard': 'Computation and Estimation',
#   'Topic': 'Multiplication'},
#  {'Question': "This graph shows the morning temperature in a city for each of four days. The morning temperature on Thursday was 3 degrees F. Based on the data in this graph, which day had a temperature closest to Thursday's temperature?",
#   'Answer': 'Monday',
#   'Wrong Answers': ['Sunday', 'Wednesday', 'Tuesday'],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Graph'},
#  {'Question': 'Which figure with less than eight angles has the most angles?',
#   'Answer': 'heptagon',
#   'Wrong Answers': ['pentagon', 'hexagon', 'decagon'],
#   'Grade_level': 4,
#   'Standard': 'Measurement and Geometry',
#   'Topic': 'Geometry'},
#  {'Question': 'Katie has 9 gallons of soda. What is the total number of pints of soda she has?',
#   'Answer': 72,
#   'Wrong Answers': [17, 48, 16],
#   'Grade_level': 4,
#   'Standard': 'Measurement and Geometry',
#   'Topic': 'Measurement'},
#  {'Question': '9 meters = ___ centimeters',
#   'Answer': 900,
#   'Wrong Answers': [700, 500, 800],
#   'Grade_level': 4,
#   'Standard': 'Measurement and Geometry',
#   'Topic': 'Measurement'},
#  {'Question': "Flora's turtle weighed 7 pounds. What is the total number of ounces Flora's turtle weighed?",
#   'Answer': 112,
#   'Wrong Answers': [23, 48, 32],
#   'Grade_level': 4,
#   'Standard': 'Measurement and Geometry',
#   'Topic': 'Measurement'},
#  {'Question': 'A lacrosse team left the school at 2:37 P.M. and returned at 7:38 P.M. What was the total amount of time that passed between the time this team left and returned to the school?',
#   'Answer': '5 hours 1 minutes',
#   'Wrong Answers': ['4 hours 57 minutes',
#    '1 hours 15 minutes',
#    '1 hours 2 minutes'],
#   'Grade_level': 4,
#   'Standard': 'Measurement and Geometry',
#   'Topic': 'Time Elapsed'},
#  {'Question': 'The table shows the time it took 4 students to run a 40 meter race. Which time was the fastest time?',
#   'Answer': 13.48,
#   'Wrong Answers': 'N/A',
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Decimal Comparison'},
#  {'Question': 'Which statement is true?',
#   'Answer': '8,431 < 8,558',
#   'Wrong Answers': ['8,558 < 8,431',
#    '8,383,108 < 8,247,076',
#    '8,354,663 < 8,203,974'],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Number Comparison'},
#  {'Question': 'How is 5,078,811 written in words?',
#   'Answer': 'five million, seventy-eight thousand, eight hundred and eleven',
#   'Wrong Answers': ['five million, seventy-eight thousand, seven hundred and eleven',
#    'five million, seventy-seven thousand, eight hundred and eleven',
#    'five million, forty-one thousand, six hundred and fifty'],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Number in Words'},
#  {'Question': 'How is 6.71 written in words?',
#   'Answer': 'six point seven one',
#   'Wrong Answers': ['six point seven',
#    'six point seven',
#    'six hundred and seventy-one'],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Decimal in Words'},
#  {'Question': 'Which of the four following numbers is smallest? 13.71, 13.16, 13.17, 13.36',
#   'Answer': 13.16,
#   'Wrong Answers': [13.71, 13.17, 13.36],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Decimal Comparison'},
#  {'Question': 'What digit is in the tenths place in 10.44?',
#   'Answer': 4,
#   'Wrong Answers': [8, 0, 5],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Decimal Place Value'},
#  {'Question': 'Which number, when rounded to the nearest whole number, is equal to 9.0?',
#   'Answer': 8.6,
#   'Wrong Answers': [7.6, 7.565, 7.515],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Decimal Rounding'},
#  {'Question': 'Order these fractions from least to greatest: 2/2, 3/2, 1/8',
#   'Answer': [0.125, 1.0, 1.5],
#   'Wrong Answers': 'N/A',
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Fraction Ordering'},
#  {'Question': 'Which fraction on the number line is the red point closest to?',
#   'Answer': 0.25,
#   'Wrong Answers': 'N/A',
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Fraction Number Line'},
#  {'Question': 'What digit is in the ten thousands place in the number 1,245,553?',
#   'Answer': 4,
#   'Wrong Answers': [1, 5, 3],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Place Value'},
#  {'Question': 'What is the value of the tens place in the number 2,108,227?',
#   'Answer': 20,
#   'Wrong Answers': [0, 7, 200],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Place Value'},
#  {'Question': 'What is 6,739,381 rounded to the nearest ten thousand?',
#   'Answer': '6,740,000',
#   'Wrong Answers': ['7,000,000', '6,739,400', '6,739,000'],
#   'Grade_level': 4,
#   'Standard': 'Number and Number Sense',
#   'Topic': 'Rounding'},
#  {'Question': 'This is an increasing pattern: 9, 14, 19, 24, 29. What rule does this pattern use?',
#   'Answer': 'Add 5',
#   'Wrong Answers': ['Add 9', 'Add 4', 'Add 8'],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Patterns'},
#  {'Question': 'The table shows the total number of players on different numbers of basketball teams in a tournament. The pattern continues in the same way. How many basketball teams are needed for a total of 77 players?',
#   'Answer': 11,
#   'Wrong Answers': [84, 13, 12],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Patterns'},
#  {'Question': 'Flora has a coin with one side heads and one side tails. Which letter on this number line best represents the probability that this coin flipped one time will land with tails facing up?',
#   'Answer': 0.5,
#   'Wrong Answers': [7, 6, 8],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Probability'},
#  {'Question': 'Sam rolls a fair number cube labeled 1 through 6. Which point represents the probability that he will roll a 5 on the first roll?',
#   'Answer': 0.16666666666666666,
#   'Wrong Answers': [1, 9, 8],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Probability'},
#  {'Question': 'Tyrek has 4 blue, 4 red, 4 yellow, and 4 purple folders in his backpack. Tyrek reaches into his backpack and selects one folder without looking. What is the likelihood the folder will be green?',
#   'Answer': 'Impossible',
#   'Wrong Answers': ['Likely, but not certain',
#    'Unlikely, but not impossible',
#    'Certain'],
#   'Grade_level': 4,
#   'Standard': 'Probability, Statistics, Patterns, Functions, and Algebra',
#   'Topic': 'Probability'}]

# %%
myclient = pymongo.MongoClient(f"mongodb://{mongo_user}:{mongo_pwd}@mongo:27017/{mongo_initdb}?authSource=admin")
#@mongo is whatever you named the service in your docker compose file and the port is the port you allocated in the file as well

# %%
questions_db = myclient['solmathdashboard']
#connects to solmathdashboard if it already exists and if it doesn't it creates it (it being your mongo DB)

# %%
#go inside database and define a new collection for the questions

collist = questions_db.list_collection_names()
#returns all the collections currently in the DB
if "questions" in collist:
    questions_db.questions.drop()
#gets rid of questions if it is in collections already (i.e. in the database)

# %%
#create questions collection
questions = questions_db['questions']

# %%
#add data to mongodb- pass in questions list
questions_insert = questions.insert_many(questions_json)

# %%
myquery = questions.find({})
pd.DataFrame.from_records(loads(dumps(myquery)))
#confirm it worked
# Out:
#                          _id  \
# 0   637e3258783e07db9c24576e
# 1   637e3258783e07db9c24576f
# 2   637e3258783e07db9c245770
# 3   637e3258783e07db9c245771
# 4   637e3258783e07db9c245772
# 5   637e3258783e07db9c245773
# 6   637e3258783e07db9c245774
# 7   637e3258783e07db9c245775
# 8   637e3258783e07db9c245776
# 9   637e3258783e07db9c245777
# 10  637e3258783e07db9c245778
# 11  637e3258783e07db9c245779
# 12  637e3258783e07db9c24577a
# 13  637e3258783e07db9c24577b
# 14  637e3258783e07db9c24577c
# 15  637e3258783e07db9c24577d
# 16  637e3258783e07db9c24577e
# 17  637e3258783e07db9c24577f
# 18  637e3258783e07db9c245780
# 19  637e3258783e07db9c245781
# 20  637e3258783e07db9c245782
# 21  637e3258783e07db9c245783
# 22  637e3258783e07db9c245784
# 23  637e3258783e07db9c245785
# 24  637e3258783e07db9c245786
# 25  637e3258783e07db9c245787
# 26  637e3258783e07db9c245788
# 27  637e3258783e07db9c245789
# 28  637e3258783e07db9c24578a
# 29  637e3258783e07db9c24578b
# 30  637e3258783e07db9c24578c
# 31  637e3258783e07db9c24578d
# 32  637e3258783e07db9c24578e
# 33  637e3258783e07db9c24578f
# 34  637e3258783e07db9c245790
# 35  637e3258783e07db9c245791
# 36  637e3258783e07db9c245792
# 37  637e3258783e07db9c245793
# 38  637e3258783e07db9c245794
# 39  637e3258783e07db9c245795
# 40  637e3258783e07db9c245796
# 41  637e3258783e07db9c245797
# 42  637e3258783e07db9c245798
# 43  637e3258783e07db9c245799
# 44  637e3258783e07db9c24579a
#
#                                              Question  \
# 0   Which number makes this equation true? 7 X ___...
# 1                                 4,305 + 1,612 = ___
# 2                                 7,784 - 1,626 = ___
# 3                                   12.1 + 12.5 = ___
# 4   Levi drinks 1.31 liters of Gatorade. Gina drin...
# 5            Which division statement represents 6/9?
# 6                    What is the sum of 7/12 and 6/6?
# 7        What is the difference between 9/4 and 4/12?
# 8   Which number is the largest common factor of 3...
# 9     What is the least common multiple of 24 and 30?
# 10  Antonio has 6 bags of 4 Skittles. Robin has 5 ...
# 11  Denari has 12 bags of 13 Reese's Pieces. How m...
# 12  Tyrek has 8 profiles with 5 Fornite skins. How...
# 13  Sam has 20 bags of 7 Skittles. How many Skittl...
# 14  Reese sold 448 Fortnite action figures. Each b...
# 15  Batman does 25 sit-ups 8 times per day. What i...
# 16            Use any method you want to find 10 X 8.
# 17                  What is the product of 69 and 75?
# 18  Gina poured 6 ounces of Gatorade into each of ...
# 19      What is the difference between 3,894 and 615?
# 20  Antonio ran a total of 90 minutes in a 2-day p...
# 21  At a store, Girlscout cookie boxes cost $26 ea...
# 22  This graph shows the morning temperature in a ...
# 23  Which figure with less than eight angles has t...
# 24  Katie has 9 gallons of soda. What is the total...
# 25                         9 meters = ___ centimeters
# 26  Flora's turtle weighed 7 pounds. What is the t...
# 27  A lacrosse team left the school at 2:37 P.M. a...
# 28  The table shows the time it took 4 students to...
# 29                           Which statement is true?
# 30                 How is 5,078,811 written in words?
# 31                      How is 6.71 written in words?
# 32  Which of the four following numbers is smalles...
# 33        What digit is in the tenths place in 10.44?
# 34  Which number, when rounded to the nearest whol...
# 35  Order these fractions from least to greatest: ...
# 36  Which fraction on the number line is the red p...
# 37  What digit is in the ten thousands place in th...
# 38  What is the value of the tens place in the num...
# 39  What is 6,739,381 rounded to the nearest ten t...
# 40  This is an increasing pattern: 9, 14, 19, 24, ...
# 41  The table shows the total number of players on...
# 42  Flora has a coin with one side heads and one s...
# 43  Sam rolls a fair number cube labeled 1 through...
# 44  Tyrek has 4 blue, 4 red, 4 yellow, and 4 purpl...
#
#                                                Answer  \
# 0                                                  11
# 1                                               5,917
# 2                                               6,158
# 3                                                24.6
# 4                                               0.947
# 5                                      6 divided by 9
# 6                                            1.583333
# 7                                            1.916667
# 8                                                  30
# 9                                                 120
# 10                                                119
# 11                                                156
# 12                                                 40
# 13                                                140
# 14                                             $2,240
# 15                                              1,400
# 16                                                 80
# 17                                              5,175
# 18                                                 12
# 19                                              3,279
# 20                                                 40
# 21                                             $1,300
# 22                                             Monday
# 23                                           heptagon
# 24                                                 72
# 25                                                900
# 26                                                112
# 27                                  5 hours 1 minutes
# 28                                              13.48
# 29                                      8,431 < 8,558
# 30  five million, seventy-eight thousand, eight hu...
# 31                                six point seven one
# 32                                              13.16
# 33                                                  4
# 34                                                8.6
# 35                                  [0.125, 1.0, 1.5]
# 36                                               0.25
# 37                                                  4
# 38                                                 20
# 39                                          6,740,000
# 40                                              Add 5
# 41                                                 11
# 42                                                0.5
# 43                                           0.166667
# 44                                         Impossible
#
#                                         Wrong Answers  Grade_level  \
# 0                                           [9, 4, 3]            4
# 1                            [10,312, 11,762, 18,083]            4
# 2                               [5,859, 5,535, 2,792]            4
# 3                                  [38.6, 31.0, 34.1]            4
# 4                   [0.95, 1.7229999999999999, 1.127]            4
# 5    [9 divided by 6, 2 divided by 8, 2 divided by 9]            4
# 6                                                 N/A            4
# 7                                                 N/A            4
# 8                                           [4, 7, 3]            4
# 9                                           [9, 3, 6]            4
# 10                                     [34, 199, 225]            4
# 11                                       [25, 81, 55]            4
# 12                                      [13, 39, 180]            4
# 13                                       [27, 15, 26]            4
# 14                             [$453, $2,424, $1,304]            4
# 15                                     [40, 216, 480]            4
# 16                                       [18, 54, 35]            4
# 17                                [144, 5,293, 2,257]            4
# 18                                         [8, 65, 9]            4
# 19                              [4,079, 4,392, 1,298]            4
# 20                                       [20, 30, 50]            4
# 21                              [$77, $1,400, $1,000]            4
# 22                       [Sunday, Wednesday, Tuesday]            4
# 23                       [pentagon, hexagon, decagon]            4
# 24                                       [17, 48, 16]            4
# 25                                    [700, 500, 800]            4
# 26                                       [23, 48, 32]            4
# 27  [4 hours 57 minutes, 1 hours 15 minutes, 1 hou...            4
# 28                                                N/A            4
# 29  [8,558 < 8,431, 8,383,108 < 8,247,076, 8,354,6...            4
# 30  [five million, seventy-eight thousand, seven h...            4
# 31  [six point seven, six point seven, six hundred...            4
# 32                              [13.71, 13.17, 13.36]            4
# 33                                          [8, 0, 5]            4
# 34                                [7.6, 7.565, 7.515]            4
# 35                                                N/A            4
# 36                                                N/A            4
# 37                                          [1, 5, 3]            4
# 38                                        [0, 7, 200]            4
# 39                  [7,000,000, 6,739,400, 6,739,000]            4
# 40                              [Add 9, Add 4, Add 8]            4
# 41                                       [84, 13, 12]            4
# 42                                          [7, 6, 8]            4
# 43                                          [1, 9, 8]            4
# 44  [Likely, but not certain, Unlikely, but not im...            4
#
#                                              Standard  \
# 0   Probability, Statistics, Patterns, Functions, ...
# 1                          Computation and Estimation
# 2                          Computation and Estimation
# 3                          Computation and Estimation
# 4                          Computation and Estimation
# 5                          Computation and Estimation
# 6                          Computation and Estimation
# 7                          Computation and Estimation
# 8                          Computation and Estimation
# 9                          Computation and Estimation
# 10                         Computation and Estimation
# 11                         Computation and Estimation
# 12                         Computation and Estimation
# 13                         Computation and Estimation
# 14                         Computation and Estimation
# 15                         Computation and Estimation
# 16                         Computation and Estimation
# 17                         Computation and Estimation
# 18                         Computation and Estimation
# 19                         Computation and Estimation
# 20                         Computation and Estimation
# 21                         Computation and Estimation
# 22  Probability, Statistics, Patterns, Functions, ...
# 23                           Measurement and Geometry
# 24                           Measurement and Geometry
# 25                           Measurement and Geometry
# 26                           Measurement and Geometry
# 27                           Measurement and Geometry
# 28                            Number and Number Sense
# 29                            Number and Number Sense
# 30                            Number and Number Sense
# 31                            Number and Number Sense
# 32                            Number and Number Sense
# 33                            Number and Number Sense
# 34                            Number and Number Sense
# 35                            Number and Number Sense
# 36                            Number and Number Sense
# 37                            Number and Number Sense
# 38                            Number and Number Sense
# 39                            Number and Number Sense
# 40  Probability, Statistics, Patterns, Functions, ...
# 41  Probability, Statistics, Patterns, Functions, ...
# 42  Probability, Statistics, Patterns, Functions, ...
# 43  Probability, Statistics, Patterns, Functions, ...
# 44  Probability, Statistics, Patterns, Functions, ...
#
#                             Topic
# 0                         Algebra
# 1            Addition/Subtraction
# 2            Addition/Subtraction
# 3    Decimal Addition/Subtraction
# 4    Decimal Addition/Subtraction
# 5                        Division
# 6   Fraction Addition/Subtraction
# 7   Fraction Addition/Subtraction
# 8                   Common Factor
# 9           Least Common Multiple
# 10                 Multiplication
# 11                 Multiplication
# 12                 Multiplication
# 13                 Multiplication
# 14                 Multiplication
# 15                 Multiplication
# 16                 Multiplication
# 17                 Multiplication
# 18                 Multiplication
# 19           Addition/Subtraction
# 20                       Division
# 21                 Multiplication
# 22                          Graph
# 23                       Geometry
# 24                    Measurement
# 25                    Measurement
# 26                    Measurement
# 27                   Time Elapsed
# 28             Decimal Comparison
# 29              Number Comparison
# 30                Number in Words
# 31               Decimal in Words
# 32             Decimal Comparison
# 33            Decimal Place Value
# 34               Decimal Rounding
# 35              Fraction Ordering
# 36           Fraction Number Line
# 37                    Place Value
# 38                    Place Value
# 39                       Rounding
# 40                       Patterns
# 41                       Patterns
# 42                    Probability
# 43                    Probability
# 44                    Probability
